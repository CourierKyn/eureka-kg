# %%
import urllib
import urllib.request
from bs4 import BeautifulSoup
import re
import random
import time
import pandas as pd

# %%
# 定位爬取文件的网站，爬取网页的html文档
soup = []
for i in list(range(11))[1:11]:
        url = "http://quotes.toscrape.com/page/" + str(i) + "/"
        req = urllib.request.Request(url)
        req.add_header("User-Agent",
                       "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.96 Safari/537.36")
        html = urllib.request.urlopen(req).read()
        soup.append(BeautifulSoup(html))
        
        
# 定位所需要的数据在html文件中的标签，找出数据        
def get_information(soup):
    quote = []
    author = []
    tags = []
    links = soup.find_all('div', class_="quote")#名言块所在的标签
    for link in links:
        link1 = link.find_all('span', class_="text")#名言块中的名言信息
        for i in link1:
            quote.append(i.get_text())
        link2 = link.find_all('small', class_="author")#名言块中的作者信息
        for i in link2:
            author.append(i.get_text())
        tags.append(link.meta.attrs['content'])#名言块中的标签信息
            
    return quote, author, tags


#将名言块中的信息提取到dataframe中
def get_quote():
    quote = []
    author = []
    tags = []
    for i in list(range(10)):
        quote.append(get_information(soup[i])[0])
        author.append(get_information(soup[i])[1])
        tags.append(get_information(soup[i])[2])
        data = pd.DataFrame(columns=['quote', 'author', 'tags'])
    for i in range(10):
        text = pd.DataFrame({"quote": quote[i],
                             "author": author[i],
                             "tags": tags[i]})
        data = data.append(text, ignore_index=True)
    return data

data
# Out:
#                                                 quote               author  \
# 0   “The world as we have created it is a process ...      Albert Einstein
# 1   “It is our choices, Harry, that show what we t...         J.K. Rowling
# 2   “There are only two ways to live your life. On...      Albert Einstein
# 3   “The person, be it gentleman or lady, who has ...          Jane Austen
# 4   “Imperfection is beauty, madness is genius and...       Marilyn Monroe
# 5   “Try not to become a man of success. Rather be...      Albert Einstein
# 6   “It is better to be hated for what you are tha...           André Gide
# 7   “I have not failed. I've just found 10,000 way...     Thomas A. Edison
# 8   “A woman is like a tea bag; you never know how...    Eleanor Roosevelt
# 9   “A day without sunshine is like, you know, nig...         Steve Martin
# 10  “This life is what you make it. No matter what...       Marilyn Monroe
# ...

# %%
import urllib
import urllib.request
from bs4 import BeautifulSoup
import re
import random
import time
import pandas as pd

# %%
#确定目标站点的URL，并读取网页的html
web_html_list = []
x = 1
for i in list(range(11))[1:11]:
    url = "http://quotes.toscrape.com/page/" + str(i) + "/"
    req = urllib.request.Request(url)
    req.add_header("User-Agent",
                   "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.96 Safari/537.36")
    html = urllib.request.urlopen(req).read()
    web_html_list.append(BeautifulSoup(html))
web_html_list
# Out:
# [<!DOCTYPE html>
#  <html lang="en">
#  <head>
#  <meta charset="utf-8"/>
#  <title>Quotes to Scrape</title>
#  <link href="/static/bootstrap.min.css" rel="stylesheet"/>
#  <link href="/static/main.css" rel="stylesheet"/>
#  </head>
#  <body>
#  <div class="container">
#  <div class="row header-box">
#  <div class="col-md-8">
#  <h1>
#  <a href="/" style="text-decoration: none">Quotes to Scrape</a>
#  </h1>
#  </div>
#  <div class="col-md-4">
#  <p>
#  <a href="/login">Login</a>
#  </p>
#  </div>
#  </div>
#  <div class="row">
#  <div class="col-md-8">
#  <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
#  <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>
#  <span>by <small class="author" itemprop="author">Albert Einstein</small>
#  <a href="/author/Albert-Einstein">(about)</a>
#  </span>
#  <div class="tags">
#              Tags:
# ...

# %%
#定位所需要的数据在一个html文件中的标签，并将数据存入list


def get_information(soup):
    quote = []
    author = []
    tags = []
    links = soup.find_all('div', class_="quote")#确定每一个名言块的位置
    for link in links:
        link1 = link.find_all('span', class_="text")#提取名言块中的名言信息
        for i in link1:
            quote.append(i.get_text())
        link2 = link.find_all('small', class_="author")#提取名言块中的作者信息
        for i in link2:
            author.append(i.get_text())
        tags.append(link.meta.attrs['content'])#提取名言块中的标签信息
    return quote, author, tags

#对多个html文件进行处理


def get_quote(soup):
    quote = []
    author = []
    tags = []
    for i in list(range(10)):
        quote.append(get_information(soup[i])[0])#将每一个页面的名言合并
        author.append(get_information(soup[i])[1])#将每一个页面的作者信息合并
        tags.append(get_information(soup[i])[2])#将每一个页面的标签信息合并
        data = pd.DataFrame(columns=['quote', 'author', 'tags'])
    for i in range(10):
        text = pd.DataFrame({"quote": quote[i],"author": author[i],"tags": tags[i]})#将每一个页面的信息放入dataframe
        data = data.append(text, ignore_index=True)#将每一个页面的dataframe合并为一个dartaframe
    return data


get_quote(web_html_list) ######## 最后一行空行
# Out:
#                                                 quote               author  \
# 0   “The world as we have created it is a process ...      Albert Einstein
# 1   “It is our choices, Harry, that show what we t...         J.K. Rowling
# 2   “There are only two ways to live your life. On...      Albert Einstein
# 3   “The person, be it gentleman or lady, who has ...          Jane Austen
# 4   “Imperfection is beauty, madness is genius and...       Marilyn Monroe
# 5   “Try not to become a man of success. Rather be...      Albert Einstein
# 6   “It is better to be hated for what you are tha...           André Gide
# 7   “I have not failed. I've just found 10,000 way...     Thomas A. Edison
# 8   “A woman is like a tea bag; you never know how...    Eleanor Roosevelt
# 9   “A day without sunshine is like, you know, nig...         Steve Martin
# 10  “This life is what you make it. No matter what...       Marilyn Monroe
# ...
